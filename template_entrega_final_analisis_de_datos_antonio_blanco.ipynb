# %% [markdown]
# # 📘 Pre-entrega
#
# **Nombre del alumno:** Antonio Blanco

# %% [markdown]
# ## 🧩 Etapa 1: Recopilación y Preparación de Datos
# **Objetivo:** Demostrar habilidades en Python, familiaridad con el entorno de trabajo y conocimientos básicos sobre manipulación de datos.

# %% [markdown]
# ### 1️⃣ Carga de datos

# %%
import pandas as pd
import numpy as np

from google.colab import drive
drive.mount('/content/drive')

import os
os.listdir('/content/drive/MyDrive/datasets')
# Out:
# Mounted at /content/drive
# ['netflix_titles.csv',
#  'reviews.csv',
#  'netflix-shows.zip',
#  'ventas.sqlite',
#  'hotels.csv',
#  'Kaggle_users.xlsx',
#  'users.csv',
#  'marketing.csv',
#  'clientes.csv',
#  'ventas.csv']

# %%
# Cargamos los datasets como DataFrames usando pandas.
df_ventas = pd.read_csv('/content/drive/MyDrive/datasets/ventas.csv')
# Verificamos utilizando .head() para visualizar las primeras filas.
df_ventas.head()
# Out:
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos

# %%
df_clientes = pd.read_csv('/content/drive/MyDrive/datasets/clientes.csv')
df_clientes.head()
# Out:
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65

# %%
df_marketing = pd.read_csv('/content/drive/MyDrive/datasets/marketing.csv')
df_marketing.head()
# Out:
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024

# %% [markdown]
# ### 2️⃣ Análisis exploratorio inicial

# %%
# TODO: Realizar un análisis exploratorio inicial de los DataFrames.
# Sugerencia: usar métodos como .info(), .describe(), .shape y .columns. dtypes.
# Esto te ayudará a entender la estructura y el contenido de los datos.
# Podés incluir comentarios sobre observaciones iniciales.
print("** Análisis exploratorio de ventas **")
print("\nCantidad de Filas y Columnas:", df_ventas.shape)
print("_"*100)
print("\nNombre de Columnas:", list(df_ventas.columns))
print("_"*100)
print("\nTipo de datos:")
print(df_ventas.dtypes)
print("_"*100)
print("\nInfo:")
df_ventas.info()
print("_"*100)
print("\nPrimeras 3 filas:")
display(df_ventas.head(3))
print("_"*100)
print("\nDescribe columnas numéricas:")
display(round(df_ventas.describe(include='number'),4))
print("_"*100)
# Out:
# ** Análisis exploratorio de ventas **
#
# Cantidad de Filas y Columnas: (3035, 6)
# ____________________________________________________________________________________________________
#
# Nombre de Columnas: ['id_venta', 'producto', 'precio', 'cantidad', 'fecha_venta', 'categoria']
# ____________________________________________________________________________________________________
#
# Tipo de datos:
# id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
# ____________________________________________________________________________________________________
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3035 entries, 0 to 3034
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_venta     3035 non-null   int64
#  1   producto     3035 non-null   object
# ...

# %%
print("** Análisis exploratorio de clientes **")
print("\nCantidad de Filas y Columnas:", df_clientes.shape)
print("_"*100)
print("\nNombre de Columnas:", list(df_clientes.columns))
print("_"*100)
print("\nTipo de datos:")
print(df_clientes.dtypes)
print("_"*100)
print("\nInfo:")
df_clientes.info()
print("_"*100)
print("\nPrimeras 3 filas:")
display(df_clientes.head(3))
print("_"*100)
print("\nDescribe columnas numéricas:")
display(round(df_clientes.describe(include='number'),4))
print("_"*100)
# Out:
# ** Análisis exploratorio de clientes **
#
# Cantidad de Filas y Columnas: (567, 5)
# ____________________________________________________________________________________________________
#
# Nombre de Columnas: ['id_cliente', 'nombre', 'edad', 'ciudad', 'ingresos']
# ____________________________________________________________________________________________________
#
# Tipo de datos:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
# ____________________________________________________________________________________________________
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_cliente  567 non-null    int64
#  1   nombre      567 non-null    object
#  2   edad        567 non-null    int64
#  3   ciudad      567 non-null    object
# ...

# %%
print("** Análisis exploratorio de marketing **")
print("\nCantidad de Filas y Columnas:", df_marketing.shape)
print("_"*100)
print("\nNombre de Columnas:", list(df_marketing.columns))
print("_"*100)
print("\nTipo de datos:")
print(df_marketing.dtypes)
print("_"*100)
print("\nInfo:")
df_marketing.info()
print("_"*100)
print("\nPrimeras 3 filas:")
display(df_marketing.head(3))
print("_"*100)
print("\nDescribe columnas numéricas:")
display(round(df_marketing.describe(include='number'),4))
print("_"*100)
# Out:
# ** Análisis exploratorio de marketing **
#
# Cantidad de Filas y Columnas: (90, 6)
# ____________________________________________________________________________________________________
#
# Nombre de Columnas: ['id_campanha', 'producto', 'canal', 'costo', 'fecha_inicio', 'fecha_fin']
# ____________________________________________________________________________________________________
#
# Tipo de datos:
# id_campanha       int64
# producto         object
# canal            object
# costo           float64
# fecha_inicio     object
# fecha_fin        object
# dtype: object
# ____________________________________________________________________________________________________
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id_campanha   90 non-null     int64
#  1   producto      90 non-null     object
# ...

# %% [markdown]
# ### 3️⃣ Calidad de los datos

# %%
# TODO: Identificar valores nulos y duplicados en los conjuntos de datos.
# Sugerencia: usar .isna().sum() y .duplicated().sum().
# Documentar las observaciones con print() o comentarios.
print("** Ventas **")
print("\nNulos por columnas:")
print(df_ventas.isna().sum())
print("_"*100)
print("\nDuplicados por columnas:",df_ventas.duplicated(keep=False).sum())
print('Duplicados por "id_venta":',df_ventas["id_venta"].duplicated(keep=False).sum())
print("_"*100)
# Out:
# ** Ventas **
#
# Nulos por columnas:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
# ____________________________________________________________________________________________________
#
# Duplicados por columnas: 70
# Duplicados por "id_venta": 70
# ____________________________________________________________________________________________________

# %%
print("** Clientes **")
print("\nNulos por columnas:")
print(df_clientes.isna().sum())
print("_"*100)
print("\nDuplicados por columnas:",df_clientes.duplicated(keep=False).sum())
print('Duplicados por "id_cliente":',df_clientes["id_cliente"].duplicated(keep=False).sum())
print("_"*100)
# Out:
# ** Clientes **
#
# Nulos por columnas:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
# ____________________________________________________________________________________________________
#
# Duplicados por columnas: 0
# Duplicados por "id_cliente": 0
# ____________________________________________________________________________________________________

# %%
print("** Marketing **")
print("\nNulos por columnas:")
print(df_marketing.isna().sum())
print("_"*100)
print("\nDuplicados por columnas:",df_marketing.duplicated(keep=False).sum())
print('Duplicados por "id_campanha":',df_marketing["id_campanha"].duplicated(keep=False).sum())
print("_"*100)
# Out:
# ** Marketing **
#
# Nulos por columnas:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
# ____________________________________________________________________________________________________
#
# Duplicados por columnas: 0
# Duplicados por "id_campanha": 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ## 🧹 Etapa 2: Preprocesamiento y Limpieza de Datos
# **Objetivo:** Demostrar conocimiento de las técnicas de limpieza y transformación de datos.

# %% [markdown]
# ### 4️⃣ Limpieza de datos

# %%
# TODO: Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados.
# Sugerencia: aplicar .drop_duplicates(), .str.strip(), .str.replace() según el caso.
# Documentar el proceso y los resultados.
df_ventas_clean = df_ventas.copy()
df_clientes_clean = df_clientes.copy()
df_marketing_clean = df_marketing.copy()

df_ventas_clean = df_ventas.drop_duplicates()
df_clientes_clean = df_clientes.drop_duplicates()
df_marketing_clean = df_marketing.drop_duplicates()

# %%
print("** Ventas Clean**")
print("\nNulos por columnas:")
print(df_ventas_clean.isna().sum())
print("_"*100)
print("\nDuplicados por columnas:",df_ventas_clean.duplicated(keep=False).sum())
print('Duplicados por "id_venta":',df_ventas_clean["id_venta"].duplicated(keep=False).sum())
print("_"*100)
# Out:
# ** Ventas Clean**
#
# Nulos por columnas:
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
# ____________________________________________________________________________________________________
#
# Duplicados por columnas: 0
# Duplicados por "id_venta": 0
# ____________________________________________________________________________________________________

# %%
# El dataset de clientes no tenian duplicados, este codigo no era necesario
print("** Clientes Clean**")
print("\nNulos por columnas:")
print(df_clientes_clean.isna().sum())
print("_"*100)
print("\nDuplicados por columnas:",df_clientes_clean.duplicated(keep=False).sum())
print('Duplicados por "id_cliente":',df_clientes_clean["id_cliente"].duplicated(keep=False).sum())
print("_"*100)
# Out:
# ** Clientes Clean**
#
# Nulos por columnas:
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
# ____________________________________________________________________________________________________
#
# Duplicados por columnas: 0
# Duplicados por "id_cliente": 0
# ____________________________________________________________________________________________________

# %%
# El dataset de marketing no tenian duplicados, este codigo no era necesario
print("** Marketing Clean**")
print("\nNulos por columnas:")
print(df_marketing_clean.isna().sum())
print("_"*100)
print("\nDuplicados por columnas:",df_marketing_clean.duplicated(keep=False).sum())
print('Duplicados por "id_campanha":',df_marketing_clean["id_campanha"].duplicated(keep=False).sum())
print("_"*100)
# Out:
# ** Marketing Clean**
#
# Nulos por columnas:
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
# ____________________________________________________________________________________________________
#
# Duplicados por columnas: 0
# Duplicados por "id_campanha": 0
# ____________________________________________________________________________________________________

# %% [markdown]
# ### 5️⃣ Transformación de datos

# %%
# TODO: Aplicar filtros y transformaciones para crear una tabla de ventas
# que muestre solo los productos con alto rendimiento. calcular el percentil 80
# y filtrar los productos que superen ese umbral en ventas.
#quantile(0.8)
# Sugerencia: usar .query() o condiciones con operadores lógicos.

# %% [markdown]
# ### 6️⃣ Agregación

# %%
# TODO: Resumir las ventas por categoría de producto y analizar los ingresos generados.
# Sugerencia: usar .groupby() y .agg() para generar métricas como suma y promedio.

# %% [markdown]
# ### 7️⃣ Integración de datos, opcional, NO OBLIGATORIO

# %%
# TODO: Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.
# Sugerencia: usar pd.merge() especificando la clave común entre ambos DataFrames.
# Documentar cualquier observación relevante sobre la combinación de datos.
